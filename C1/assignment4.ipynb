# %% [markdown]
# # Assignment 4
# ## Description
# In this assignment you must read in a file of metropolitan regions and associated sports teams from [assets/wikipedia_data.html](assets/wikipedia_data.html) and answer some questions about each metropolitan region. Each of these regions may have one or more teams from the "Big 4": NFL (football, in [assets/nfl.csv](assets/nfl.csv)), MLB (baseball, in [assets/mlb.csv](assets/mlb.csv)), NBA (basketball, in [assets/nba.csv](assets/nba.csv) or NHL (hockey, in [assets/nhl.csv](assets/nhl.csv)). Please keep in mind that all questions are from the perspective of the metropolitan region, and that this file is the "source of authority" for the location of a given sports team. Thus teams which are commonly known by a different area (e.g. "Oakland Raiders") need to be mapped into the metropolitan region given (e.g. San Francisco Bay Area). This will require some human data understanding outside of the data you've been given (e.g. you will have to hand-code some names, and might need to google to find out where teams are)!
#
# For each sport I would like you to answer the question: **what is the win/loss ratio's correlation with the population of the city it is in?** Win/Loss ratio refers to the number of wins over the number of wins plus the number of losses. Remember that to calculate the correlation with [`pearsonr`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html), so you are going to send in two ordered lists of values, the populations from the wikipedia_data.html file and the win/loss ratio for a given sport in the same order. Average the win/loss ratios for those cities which have multiple teams of a single sport. Each sport is worth an equal amount in this assignment (20%\*4=80%) of the grade for this assignment. You should only use data **from year 2018** for your analysis -- this is important!
#
# ## Notes
#
# 1. Do not include data about the MLS or CFL in any of the work you are doing, we're only interested in the Big 4 in this assignment.
# 2. I highly suggest that you first tackle the four correlation questions in order, as they are all similar and worth the majority of grades for this assignment. This is by design!
# 3. It's fair game to talk with peers about high level strategy as well as the relationship between metropolitan areas and sports teams. However, do not post code solving aspects of the assignment (including such as dictionaries mapping areas to teams, or regexes which will clean up names).
# 4. There may be more teams than the assert statements test, remember to collapse multiple teams in one city into a single value!

# %% [markdown]
# ## Question 1
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NHL** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nhl_df=pd.read_csv("assets/nhl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nhl_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nhl_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q1: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q1: There should be 28 teams being analysed for NHL"
    
    return stats.pearsonr(population_by_region, win_loss_by_region)

# %%
# experiments

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nhl_df=pd.read_csv("assets/nhl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]

# NHL TEAMS
nhl_df = nhl_df[(nhl_df['GP'] == str(82)) & (nhl_df['year'] == 2018)]
nhl_df['city']=nhl_df['team'].str.extract(r'^([\w.]{1,5}(?:\s\w+)?\w*)')
nhl_df['team'] = nhl_df['team'].str.replace('*','')
nhl_df["team"] = nhl_df["team"].apply(lambda x: x.split(" ")[-1])
# nhl_df
# CITIES

cities.NHL.replace('—', np.nan, inplace = True) # Replace dash(-) with nan
cities.NHL.value_counts()
replace_values = {
    "RangersIslandersDevils": "Rangers,Islanders,Devils",
    "KingsDucks": "Kings,Ducks",
    "Red Wings": "Red,Wings", 
    "Maple Leafs": "Maple,Leafs", 
    "Blue Jackets": "Blue,Jackets",
    "Golden Knights": "Golden,Knights" 
}
cities["NHL"] = cities["NHL"].apply(lambda x: re.sub(r"\[.+\]", "", str(x))) # Remove [value]
cities['NHL'] = cities.NHL.replace(replace_values)
cities.rename(columns = {'Population (2016 est.)[8]' : 'Population'})
cities["NHL"] = cities["NHL"].apply(lambda x: x.split(","))
cities = cities.explode("NHL")
cities
# Out:
#          Metropolitan area        Country Pop.rank Population (2016 est.)[8]  \
# 0            New York City  United States        1                  20153634
# 0            New York City  United States        1                  20153634
# 0            New York City  United States        1                  20153634
# 1              Los Angeles  United States        2                  13310447
# 1              Los Angeles  United States        2                  13310447
# 2   San Francisco Bay Area  United States        6                   6657982
# 3                  Chicago  United States        3                   9512999
# 4        Dallas–Fort Worth  United States        4                   7233323
# 5         Washington, D.C.  United States        7                   6131977
# 6             Philadelphia  United States        8                   6070500
# 7                   Boston  United States       12                   4794447
# 8   Minneapolis–Saint Paul  United States       17                   3551036
# 9                   Denver  United States       20                   2853077
# 10   Miami–Fort Lauderdale  United States        9                   6066387
# 11                 Phoenix  United States       13                   4661537
# 12                 Detroit  United States       14                   4297617
# 12                 Detroit  United States       14                   4297617
# 13                 Toronto         Canada       10                   5928040
# 13                 Toronto         Canada       10                   5928040
# 14                 Houston  United States        5                   6772470
# 15                 Atlanta  United States       11                   5789700
# 16          Tampa Bay Area  United States       19                   3032171
# 17              Pittsburgh  United States       28                   2342299
# 18               Cleveland  United States       33                   2055612
# 19                 Seattle  United States       16                   3798902
# 20              Cincinnati  United States       30                   2165139
# 21             Kansas City  United States       32                   2104509
# 22               St. Louis  United States       21                   2807002
# 23               Baltimore  United States       22                   2798886
# 24               Charlotte  United States       23                   2474314
# 25            Indianapolis  United States       35                   2004230
# 26               Nashville  United States       36                   1865298
# 27               Milwaukee  United States       37                   1572482
# 28             New Orleans  United States       45                   1268883
# 29                 Buffalo  United States       47                   1132804
# 30                Montreal         Canada       15                   4098927
# 31               Vancouver         Canada       24                   2463431
# 32                 Orlando  United States       25                   2441257
# 33                Portland  United States       27                   2424955
# 34                Columbus  United States       34                   2041520
# 34                Columbus  United States       34                   2041520
# 35                 Calgary         Canada       39                   1392609
# 36                  Ottawa         Canada       42                   1323783
# 37                Edmonton         Canada       43                   1321426
# 38          Salt Lake City  United States       46                   1186187
# 39                Winnipeg         Canada       67                    778489
# 40               San Diego  United States       18                   3317749
# 41             San Antonio  United States       26                   2429609
# 42              Sacramento  United States       29                   2296418
# 43               Las Vegas  United States       31                   2155664
# 43               Las Vegas  United States       31                   2155664
# 44            Jacksonville  United States       38                   1478212
# 45           Oklahoma City  United States       40                   1373211
# 46                 Memphis  United States       41                   1342842
# 47                 Raleigh  United States       44                   1302946
# 48               Green Bay  United States        —                    318236
# 49                Hamilton         Canada        —                    747545
# 50                  Regina         Canada        —                    236481
# 51                  Totals              —        —                         –
#
#      B4                   NFL                  MLB                 NBA  \
# 0     9    GiantsJets[note 1]  YankeesMets[note 2]          KnicksNets
# 0     9    GiantsJets[note 1]  YankeesMets[note 2]          KnicksNets
# 0     9    GiantsJets[note 1]  YankeesMets[note 2]          KnicksNets
# 1     8  RamsChargers[note 4]        DodgersAngels      LakersClippers
# 1     8  RamsChargers[note 4]        DodgersAngels      LakersClippers
# 2     6  49ersRaiders[note 6]      GiantsAthletics            Warriors
# 3     5         Bears[note 8]        CubsWhite Sox       Bulls[note 9]
# 4     4               Cowboys              Rangers           Mavericks
# 5     4              Redskins   Nationals[note 10]    Wizards[note 11]
# 6     4                Eagles    Phillies[note 12]               76ers
# 7     4     Patriots[note 14]     Red Sox[note 15]             Celtics
# 8     4               Vikings                Twins        Timberwolves
# 9     4               Broncos              Rockies    Nuggets[note 17]
# 10    4              Dolphins              Marlins                Heat
# 11    4             Cardinals         Diamondbacks                Suns
# 12    4                 Lions      Tigers[note 20]    Pistons[note 21]
# 12    4                 Lions      Tigers[note 20]    Pistons[note 21]
# 13    3           — [note 22]            Blue Jays    Raptors[note 23]
# 13    3           — [note 22]            Blue Jays    Raptors[note 23]
# 14    3       Texans[note 24]               Astros             Rockets
# 15    3               Falcons               Braves               Hawks
# 16    3            Buccaneers                 Rays                   —
# 17    3              Steelers              Pirates           [note 27]
# 18    3       Browns[note 29]     Indians[note 30]  Cavaliers[note 31]
# 19    2              Seahawks             Mariners           [note 33]
# 20    2               Bengals        Reds[note 35]           [note 36]
# 21    2                Chiefs      Royals[note 37]           [note 38]
# 22    2             [note 40]   Cardinals[note 41]           [note 42]
# 23    2       Ravens[note 45]     Orioles[note 46]           [note 47]
# 24    2              Panthers                    —    Hornets[note 49]
# 25    2                 Colts            [note 50]     Pacers[note 51]
# 26    2                Titans                    —                   —
# 27    2             [note 53]     Brewers[note 54]               Bucks
# 28    2                Saints                    —   Pelicans[note 55]
# 29    2        Bills[note 56]            [note 57]           [note 58]
# 30    1                     —            [note 59]                   —
# 31    1                     —                    —           [note 60]
# 32    1                     —                    —               Magic
# 33    1                     —                    —       Trail Blazers
# 34    1                     —                    —                   —
# 34    1                     —                    —                   —
# 35    1                     —                    —                   —
# 36    1                     —                    —                   —
# 37    1                     —                    —                   —
# 38    1                     —                    —                Jazz
# 39    1                     —                    —                   —
# 40    1             [note 62]               Padres           [note 63]
# 41    1             [note 64]                    —               Spurs
# 42    1                     —                    —               Kings
# 43    1              [note 6]                    —                   —
# 43    1              [note 6]                    —                   —
# 44    1               Jaguars                    —                   —
# 45    1                     —                    —    Thunder[note 68]
# 46    1             [note 69]                    —           Grizzlies
# 47    1                     —                    —                   —
# 48    1               Packers                    —                   —
# 49    0                     —                    —                   —
# 50    0                     —                    —                   —
# 51  123                    32                   30                  30
#
#            NHL   B6                           MLS           CFL
# 0      Rangers   11     Red BullsNew York City FC             —
# 0    Islanders   11     Red BullsNew York City FC             —
# 0       Devils   11     Red BullsNew York City FC             —
# 1        Kings   10  GalaxyLos Angeles FC[note 5]             —
# 1        Ducks   10  GalaxyLos Angeles FC[note 5]             —
# 2       Sharks    7                   Earthquakes             —
# 3   Blackhawks    6                          Fire             —
# 4        Stars    5                     FC Dallas             —
# 5     Capitals    5                   D.C. United             —
# 6       Flyers    5                         Union             —
# 7       Bruins    5                    Revolution             —
# 8         Wild    5                     United FC             —
# 9    Avalanche    5                        Rapids             —
# 10    Panthers    4                     [note 19]             —
# 11     Coyotes    4                             —             —
# 12         Red    4                             —             —
# 12       Wings    4                             —             —
# 13       Maple    5                    Toronto FC     Argonauts
# 13       Leafs    5                    Toronto FC     Argonauts
# 14         nan    4                        Dynamo             —
# 15                4                     United FC             —
# 16   Lightning    3                     [note 26]             —
# 17    Penguins    3                             —             —
# 18                3                             —             —
# 19                3                   Sounders FC             —
# 20         nan    3                 FC Cincinnati             —
# 21                3          Sporting Kansas City             —
# 22       Blues    2                     [note 44]             —
# 23         nan    2                             —     [note 48]
# 24         nan    2                             —             —
# 25         nan    2                             —             —
# 26   Predators    2                     [note 52]             —
# 27         nan    2                             —             —
# 28         nan    2                             —             —
# 29      Sabres    2                             —             —
# 30   Canadiens    3                        Impact     Alouettes
# 31     Canucks    3                  Whitecaps FC         Lions
# 32         nan    2               Orlando City SC             —
# 33         nan    2                       Timbers             —
# 34        Blue    2                       Crew SC             —
# 34     Jackets    2                       Crew SC             —
# 35      Flames    2                             —    Stampeders
# 36    Senators    2                             —     Redblacks
# 37      Oilers    2                             —       Eskimos
# 38         nan    2                Real Salt Lake             —
# 39        Jets    2                             —  Blue Bombers
# 40         nan    1                             —             —
# 41         nan    1                             —     [note 65]
# 42         nan    1                             —     [note 66]
# 43      Golden    1                             —     [note 67]
# 43     Knights    1                             —     [note 67]
# 44         nan    1                             —             —
# 45         nan    1                             —             —
# 46         nan    1                             —     [note 70]
# 47  Hurricanes    1                             —             —
# 48         nan    1                             —             —
# 49                1                             —    Tiger-Cats
# 50         nan    1                             —   Roughriders
# 51          31  156                   24[note 72]             9

# %%
nhl_df
# Out:
#           team  GP   W   L  OL  PTS  PTS%   GF   GA    SRS    SOS  RPt% ROW  \
# 1    Lightning  82  54  23   5  113  .689  296  236   0.66  -0.07  .634  48
# 2       Bruins  82  50  20  12  112  .683  270  214   0.62  -0.07  .610  47
# 3        Leafs  82  49  26   7  105  .640  277  232   0.49  -0.06  .567  42
# 4     Panthers  82  44  30   8   96  .585  248  246  -0.01  -0.04  .537  41
# 5        Wings  82  30  39  13   73  .445  217  255  -0.48  -0.01  .341  25
# 6    Canadiens  82  29  40  13   71  .433  209  264  -0.68   0.00  .378  27
# 7     Senators  82  28  43  11   67  .409  221  291  -0.85   0.00  .372  26
# 8       Sabres  82  25  45  12   62  .378  199  280  -0.98   0.01  .311  24
# 10    Capitals  82  49  26   7  105  .640  259  239   0.21  -0.04  .585  46
# 11    Penguins  82  47  29   6  100  .610  272  250   0.23  -0.04  .573  45
# 12      Flyers  82  42  26  14   98  .598  251  243   0.07  -0.03  .543  40
# 13     Jackets  82  45  30   7   97  .591  242  230   0.11  -0.04  .537  39
# 14      Devils  82  44  29   9   97  .591  248  244   0.02  -0.03  .530  39
# 15  Hurricanes  82  36  35  11   83  .506  228  256  -0.35  -0.01  .439  33
# 16   Islanders  82  35  37  10   80  .488  264  296  -0.40  -0.01  .427  32
# 17     Rangers  82  34  39   9   77  .470  231  268  -0.46  -0.01  .427  31
# 19   Predators  82  53  18  11  117  .713  267  211   0.71   0.03  .652  47
# 20        Jets  82  52  20  10  114  .695  277  218   0.74   0.02  .622  48
# 21        Wild  82  45  26  11  101  .616  253  232   0.29   0.04  .549  42
# 22   Avalanche  82  43  30   9   95  .579  257  237   0.28   0.04  .518  41
# 23       Blues  82  44  32   6   94  .573  226  222   0.10   0.05  .518  41
# 24       Stars  82  42  32   8   92  .561  235  225   0.17   0.04  .506  38
# 25  Blackhawks  82  33  39  10   76  .463  229  256  -0.26   0.07  .409  32
# 27     Knights  82  51  24   7  109  .665  272  228   0.52  -0.01  .616  47
# 28       Ducks  82  44  25  13  101  .616  235  216   0.24   0.01  .555  40
# 29      Sharks  82  45  27  10  100  .610  252  229   0.28   0.00  .537  40
# 30       Kings  82  45  29   8   98  .598  239  203   0.44   0.00  .543  43
# 31      Flames  82  37  35  10   84  .512  218  248  -0.33   0.03  .470  35
# 32      Oilers  82  36  40   6   78  .476  234  263  -0.32   0.03  .415  31
# 33     Canucks  82  31  40  11   73  .445  218  264  -0.51   0.05  .409  31
# 34     Coyotes  82  29  41  12   70  .427  208  256  -0.53   0.05  .372  27
#
#     year League          city
# 1   2018    NHL     Tampa Bay
# 2   2018    NHL        Boston
# 3   2018    NHL       Toronto
# 4   2018    NHL       Florida
# 5   2018    NHL       Detroit
# 6   2018    NHL      Montreal
# 7   2018    NHL        Ottawa
# 8   2018    NHL       Buffalo
# 10  2018    NHL    Washington
# 11  2018    NHL    Pittsburgh
# 12  2018    NHL  Philadelphia
# 13  2018    NHL      Columbus
# 14  2018    NHL    New Jersey
# 15  2018    NHL      Carolina
# 16  2018    NHL      New York
# 17  2018    NHL      New York
# 19  2018    NHL     Nashville
# 20  2018    NHL      Winnipeg
# 21  2018    NHL     Minnesota
# 22  2018    NHL      Colorado
# 23  2018    NHL     St. Louis
# 24  2018    NHL        Dallas
# 25  2018    NHL       Chicago
# 27  2018    NHL  Vegas Golden
# 28  2018    NHL       Anaheim
# 29  2018    NHL      San Jose
# 30  2018    NHL   Los Angeles
# 31  2018    NHL       Calgary
# 32  2018    NHL      Edmonton
# 33  2018    NHL     Vancouver
# 34  2018    NHL       Arizona

# %% [markdown]
# ## Question 2
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NBA** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nba_df=pd.read_csv("assets/nba.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nba_correlation():
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nba_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q2: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q2: There should be 28 teams being analysed for NBA"

    return stats.pearsonr(population_by_region, win_loss_by_region)

# %% [markdown]
# ## Question 3
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **MLB** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

mlb_df=pd.read_csv("assets/mlb.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def mlb_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from mlb_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q3: Your lists must be the same length"
    assert len(population_by_region) == 26, "Q3: There should be 26 teams being analysed for MLB"

    return stats.pearsonr(population_by_region, win_loss_by_region)

# %% [markdown]
# ## Question 4
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NFL** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nfl_df=pd.read_csv("assets/nfl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nfl_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nfl_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q4: Your lists must be the same length"
    assert len(population_by_region) == 29, "Q4: There should be 29 teams being analysed for NFL"

    return stats.pearsonr(population_by_region, win_loss_by_region)

# %% [markdown]
# ## Question 5
# In this question I would like you to explore the hypothesis that **given that an area has two sports teams in different sports, those teams will perform the same within their respective sports**. How I would like to see this explored is with a series of paired t-tests (so use [`ttest_rel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html)) between all pairs of sports. Are there any sports where we can reject the null hypothesis? Again, average values where a sport has multiple teams in one region. Remember, you will only be including, for each sport, cities which have teams engaged in that sport, drop others as appropriate. This question is worth 20% of the grade for this assignment.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

mlb_df=pd.read_csv("assets/mlb.csv")
nhl_df=pd.read_csv("assets/nhl.csv")
nba_df=pd.read_csv("assets/nba.csv")
nfl_df=pd.read_csv("assets/nfl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def sports_team_performance():
    # YOUR CODE HERE
    raise NotImplementedError()
    
    # Note: p_values is a full dataframe, so df.loc["NFL","NBA"] should be the same as df.loc["NBA","NFL"] and
    # df.loc["NFL","NFL"] should return np.nan
    sports = ['NFL', 'NBA', 'NHL', 'MLB']
    p_values = pd.DataFrame({k:np.nan for k in sports}, index=sports)
    
    assert abs(p_values.loc["NBA", "NHL"] - 0.02) <= 1e-2, "The NBA-NHL p-value should be around 0.02"
    assert abs(p_values.loc["MLB", "NFL"] - 0.80) <= 1e-2, "The MLB-NFL p-value should be around 0.80"
    return p_values
